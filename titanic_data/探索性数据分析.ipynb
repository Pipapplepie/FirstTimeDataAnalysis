# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train_chinese.csv')

# %%
# Create a dataframe

data = np.arange(8).reshape(2,4)  # 2*4 matrix

# %%
df_num = pd.DataFrame(data, columns = ['a', 'd', 'c', 'b'], index = [2,1])
df_num
# Out:
#    a  d  c  b
# 2  0  1  2  3
# 1  4  5  6  7

# %%
# Order by columns/ indexes in ascending fashion

df_num.sort_index()  # method 1
# Out:
#    a  d  c  b
# 1  4  5  6  7
# 2  0  1  2  3

# %%
df_num.reindex(sorted(df_num.index))  # method 2
# Out:
#    a  d  c  b
# 1  4  5  6  7
# 2  0  1  2  3

# %%
df_num.sort_index(axis = 1)  # sort columns
                             # axis : index, columns to direct sorting
# Out:
#    a  b  c  d
# 2  0  3  2  1
# 1  4  7  6  5

# %%
df_num.reindex(sorted(df_num.columns), axis=1)
# Out:
#    a  b  c  d
# 2  0  3  2  1
# 1  4  7  6  5

# %%
df_num.sort_index(axis = 1, ascending = False)  # True by default
# Out:
#    d  c  b  a
# 2  1  2  3  0
# 1  5  6  7  4

# %%
df_num.sort_index(ascending = False)  # descending
# Out:
#    a  d  c  b
# 2  0  1  2  3
# 1  4  5  6  7

# %%
df_num.sort_values(by=['a', 'c'], ascending=False)
# Out:
#    a  d  c  b
# 1  4  5  6  7
# 2  0  1  2  3

# %%
# Sort by column values

df = df.sort_values(by=['票价','年龄'], ascending=False)
df.head(20)
# Out:
#      Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 679         679   680     1               1
# 258         258   259     1               1
# 737         737   738     1               1
# 438         438   439     0               1
# 341         341   342     1               1
# 88           88    89     1               1
# 27           27    28     0               1
# 742         742   743     1               1
# 311         311   312     1               1
# 299         299   300     1               1
# 118         118   119     0               1
# 380         380   381     1               1
# 716         716   717     1               1
# 700         700   701     1               1
# 557         557   558     0               1
# 527         527   528     0               1
# 377         377   378     0               1
# 779         779   780     1               1
# 730         730   731     1               1
# 689         689   690     1               1
#
# ...

# %%
df = df.sort_values(by=['乘客等级(1/2/3等舱位)'], ascending=True)
df.head(20)

#  The first 20 passengers all survived. It is probable that Pclass is closely related to Survived
# Out:
#      Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 737         737   738     1               1
# 887         887   888     1               1
# 842         842   843     1               1
# 853         853   854     1               1
# 539         539   540     1               1
# 710         710   711     1               1
# 571         571   572     1               1
# 457         457   458     1               1
# 669         669   670     1               1
# 383         383   384     1               1
# 871         871   872     1               1
# 809         809   810     1               1
# 3             3     4     1               1
# 166         166   167     1               1
# 356         356   357     1               1
# 577         577   578     1               1
# 309         309   310     1               1
# 781         781   782     1               1
# 329         329   330     1               1
# 513         513   514     1               1
#
# ...

# %%
df = df.sort_values(by=['乘客等级(1/2/3等舱位)'], ascending=False)
df.head(20)

# Only 3 out of 20 survived
# Out:
#      Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 192         192   193     1               3
# 744         744   745     1               3
# 616         616   617     0               3
# 751         751   752     1               3
# 188         188   189     0               3
# 46           46    47     0               3
# 825         825   826     0               3
# 495         495   496     0               3
# 623         623   624     0               3
# 704         704   705     0               3
# 364         364   365     0               3
# 73           73    74     0               3
# 569         569   570     1               3
# 392         392   393     0               3
# 411         411   412     0               3
# 115         115   116     0               3
# 794         794   795     0               3
# 189         189   190     0               3
# 29           29    30     0               3
# 16           16    17     0               3
#
# ...

# %%
df = df[df['性别'] == 'female']
df = df.sort_values(by=['乘客等级(1/2/3等舱位)'], ascending=True)
df.head(20)

# female = 19/20 survived
# male   =  7/20 survived
# Out:
#      Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 710         710   711     1               1
# 708         708   709     1               1
# 230         230   231     1               1
# 700         700   701     1               1
# 689         689   690     1               1
# 820         820   821     1               1
# 218         218   219     1               1
# 215         215   216     1               1
# 496         496   497     1               1
# 716         716   717     1               1
# 435         435   436     1               1
# 556         556   557     1               1
# 88           88    89     1               1
# 742         742   743     1               1
# 498         498   499     0               1
# 730         730   731     1               1
# 457         457   458     1               1
# 1             1     2     1               1
# 763         763   764     1               1
# 504         504   505     1               1
#
# ...

# %%
# Run the 2nd code block first to restore the data

df = df.sort_values(by=['年龄'], ascending=False)
df.head(20)

# Ascending:  13/20
# Descending:  5/20
# Out:
#      Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 630         630   631     1               1
# 851         851   852     0               3
# 96           96    97     0               1
# 493         493   494     0               1
# 116         116   117     0               3
# 745         745   746     0               1
# 672         672   673     0               2
# 33           33    34     0               2
# 456         456   457     0               1
# 280         280   281     0               3
# 54           54    55     0               1
# 438         438   439     0               1
# 545         545   546     0               1
# 483         483   484     1               3
# 275         275   276     1               1
# 555         555   556     0               1
# 570         570   571     1               2
# 829         829   830     1               1
# 252         252   253     0               1
# 625         625   626     0               1
#
# ...

# %%
'''
People of higher Pclass are more likely to survive.
It is also probable that female passengers and the kids are prioritized when escaping.
'''
# Out:
# '\nPeople of higher Pclass are more likely to survive.\nIt is also probable that female passengers and the kids are prioritized when escaping.\n'

# %%
# Arithmetic

data_1 = np.arange(6).reshape(2,3)
data_2 = np.arange(12).reshape(3,4)

df_1 = pd.DataFrame(data_1, index = [1,2], columns = ['a', 'b', 'c'])
df_2 = pd.DataFrame(data_2, index = [1, 'two', 'three'], columns = ['a', 'b', 3, 4])

df_1 + df_2
# Out:
#         3   4    a    b   c
# 1     NaN NaN  0.0  2.0 NaN
# 2     NaN NaN  NaN  NaN NaN
# three NaN NaN  NaN  NaN NaN
# two   NaN NaN  NaN  NaN NaN

# %%
max(df['堂兄弟/妹个数'] + df['父母与小孩个数'])
# Out:
# 10

# %%
family = df['堂兄弟/妹个数'] + df['父母与小孩个数']
family = pd.Series(family, name = '家庭成员总数')
df_fam = df.join(family)
df_fam.head()
# Out:
#    Unnamed: 0  乘客ID  是否幸存  乘客等级(1/2/3等舱位)  \
# 0           0     1     0               3
# 1           1     2     1               1
# 2           2     3     1               3
# 3           3     4     1               1
# 4           4     5     0               3
#
#                                                 乘客姓名      性别    年龄  堂兄弟/妹个数  \
# 0                            Braund, Mr. Owen Harris    male  22.0        1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0        1
# 2                             Heikkinen, Miss. Laina  female  26.0        0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0        1
# 4                           Allen, Mr. William Henry    male  35.0        0
#
#    父母与小孩个数              船票信息       票价    客舱 登船港口  家庭成员总数
# 0        0         A/5 21171   7.2500   NaN    S       1
# 1        0          PC 17599  71.2833   C85    C       1
# 2        0  STON/O2. 3101282   7.9250   NaN    S       0
# ...

# %%
df_fam['家庭成员总数'].describe()  # get max == 10
# Out:
# count    891.000000
# mean       0.904602
# std        1.613459
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       10.000000
# Name: 家庭成员总数, dtype: float64

# %%
# describe()

df_num.describe()
# Out:
#               a         d         c         b
# count  2.000000  2.000000  2.000000  2.000000
# mean   2.000000  3.000000  4.000000  5.000000
# std    2.828427  2.828427  2.828427  2.828427
# min    0.000000  1.000000  2.000000  3.000000
# 25%    1.000000  2.000000  3.000000  4.000000
# 50%    2.000000  3.000000  4.000000  5.000000
# 75%    3.000000  4.000000  5.000000  6.000000
# max    4.000000  5.000000  6.000000  7.000000

# %%
df[['票价','父母与小孩个数']].describe()
# Out:
#                票价     父母与小孩个数
# count  891.000000  891.000000
# mean    32.204208    0.381594
# std     49.693429    0.806057
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    0.000000
# max    512.329200    6.000000

# %%
'''
Most passengers (mor than 75%) don't have parents or kids.
And the Ticket price are mostly (75%) less than the mean, which means only few people buy expensive tickets (probably 1st class).
'''
# Out:
# "\nMost passengers (mor than 75%) don't have parents or kids.\nAnd the Ticket price are mostly (75%) less than the mean, which means only few people buy expensive tickets (probably 1st class).\n"

# %%
df['乘客等级(1/2/3等舱位)'].describe()

'''
This is consistent with our previous hypothesis: less than a quarter people in 1st class.
'''
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: 乘客等级(1/2/3等舱位), dtype: float64

# %%
df['是否幸存'].describe()  

# Less than 40% people in total survived
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: 是否幸存, dtype: float64

# %%
df = df[df['乘客等级(1/2/3等舱位)'] == 1]
df['是否幸存'].describe()

# About 60% Pclass 1 passengers survived.
# Out:
# count    216.000000
# mean       0.629630
# std        0.484026
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: 是否幸存, dtype: float64

# %%
df = df[df['性别'] == 'male']
df[['是否幸存']].describe()

# More than 70% female survived
# Less than 20% male survived

'''
This result is consistent with our hypothesis: 
female passengers might be prioritized in escaping.
(Just like the Titanic movie!)
'''
# Out:
# '\nThis result is consistent with our hypothesis: \nfemale passengers might be prioritized in escaping.\n(Just like the Titanic movie!)\n'

# %%
df = df[(df['年龄'] > 60)]
df[['是否幸存']].describe()

# Only about 20% old people survived
# Out:
#             是否幸存
# count  22.000000
# mean    0.227273
# std     0.428932
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.000000
# max     1.000000

# %%
df = df[(df['年龄'] < 16)]
df[['是否幸存']].describe()

# About 60% kids survived

'''
This result is consistent with our hypothesis: 
Kids/ Young passengers might be prioritized in escaping.
'''
# Out:
#             是否幸存
# count  83.000000
# mean    0.590361
# std     0.494757
# min     0.000000
# 25%     0.000000
# 50%     1.000000
# 75%     1.000000
# max     1.000000
